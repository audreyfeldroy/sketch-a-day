# %%
size(400, 400)
background('#00FFFF')
fill('#FF0000')
rect(150, 150, 100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

# Blue sky background
background('#00FFFF')

# 2 orange squares in center, one on top of the other
fill('#FFA500')
rect(150, 100, 100, 100)
rect(150, 200, 100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

# Blue sky background
background('#00FFFF')

# 3 yellow squares in center, one on top of the other
fill('#FFFF00')
rect(150, 50, 100, 100)
rect(150, 150, 100, 100)
rect(150, 250, 100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

# Blue sky background
background('#00FFFF')

# 4 green squares in center, a square made up of 4 squares
fill('#00FF00')
rect(100, 200, 100, 100)
rect(100, 100, 100, 100)
rect(200, 100, 100, 100)
rect(200, 200, 100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

# Blue sky background
background('#00FFFF')

# Draw Numberblock One
# 1 red square in center
fill('#FF0000')
rect(150, 150, 100, 100)

# 2 squashed dark red sausage shapes for arms (tear shapes)
fill('#8B0000')
ellipse(150, 250, 50, 20)
ellipse(250, 250, 50, 20)

# 2 squashed sausage shapes for legs

# 1 white circle with a thick dark red stroke for the eye

# Curved oval smile

# Number 1 above the character
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
