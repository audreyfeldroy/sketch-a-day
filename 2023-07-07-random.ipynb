# %% [markdown]
# # 2023-07-07
#
# * Python 3.11.3
# * py5

# %% [markdown]
# Just installing plain py5 because `pip install py5[jupyter]` failed

# %%
# !pip install py5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 220.2 kB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.2/590.2 kB 128.2 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 1.7 MB/s eta 0:00:00ta 0:00:01
# ...
#   Using cached numpy-1.25.0-cp311-cp311-macosx_10_9_x86_64.whl (20.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 260.5 kB/s eta 0:00:0000:0100:01
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached pycodestyle-2.10.0-py2.py3-none-any.whl (41 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.9/731.9 kB 221.8 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 41.8 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 10.5 kB/s eta 0:00:00a 0:00:02
# ...

# %%
import py5
# Out:
# Importing py5 on OSX but the necessary Jupyter OSX event loop has not been activated. I'll activate it for you, but next time, execute `%gui osx` before importing this library.

# %%
# %gui osx

# %% [markdown]
# Module Mode lets you write standalone settings, setup, and draw methods:

# %%
def setup():
    py5.size(200, 200)
    py5.rect_mode(py5.CENTER)

# %%
def draw():
    py5.rect(py5.mouse_x, py5.mouse_y, 10, 10)

# %%
py5.run_sketch()

# %% [markdown]
# # Py5 Jupyter Setup
#
# pip install py5[jupyter] installs py5 and py5jupyter at the same time. In this notebook we do them separately, but it's good to know.

# %%
# !pip install py5jupyter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# ...
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# ...

# %% [markdown]
# Install the py5 kernel for imported mode Sketches:

# %%
# !python -m py5jupyter.kernels.py5.install --sys-prefix
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installing py5 Jupyter kernel spec

# %% [markdown]
# Install py5bot for static mode sketches:

# %%
# !python -m py5jupyter.kernels.py5bot.install --sys-prefix
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installing py5bot Jupyter kernel spec

# %% [markdown]
# Static Mode lets you create static images using functionless code:

# %%
from py5jupyter.kernels.py5bot import Py5Bot
from py5jupyter.kernels.py5 import Py5,

# %%
size(300, 200)
rect_mode(CENTER)
for _ in range(20):
    rect(random_int(width), random_int(height), 10, 10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/8n/8bp9lk9n1sj1cfb11k87mgdc0000gn/T/ipykernel_98089/1597223793.py in ?()
# ----> 1 size(300, 200)
#       2 rect_mode(CENTER)
#       3 for _ in range(20):
#       4     rect(random_int(width), random_int(height), 10, 10)
#
# ~/code/art-repos/sketch-a-day/.venv/lib/python3.11/site-packages/py5/__init__.py in ?(*args)
#   13299     will not exit and the output file will be empty. If you would like to draw 3D
#   13300     objects to a PDF or SVG file, use the `P3D` renderer and the strategy described
#   13301     in `begin_raw()`.
#   13302     """
# > 13303     return _py5sketch.size(*args)
#
# ~/code/art-repos/sketch-a-day/.venv/lib/python3.11/site-packages/py5/sketch.py in ?(self_, *args)
#     114         def decorated(self_, *args):
#     115             if self_._py5_bridge.current_running_method == 'settings':
# ...

# %% [markdown]
# None of the py5bot kernel stuff above worked, so I switched to the terminal and ran:
#
# ```
# pip install ipykernel
# pip install py5jupyter
# python -m py5jupyter.kernels.py5.install --sys-prefix
# jupyter notebook
# ```
#
# Then I clicked on the running kernel > Change kernel > and pasted the URL from the terminal, which looked something like:
# http://localhost:8888/?token=blahblahblah
#
# Now static mode works:

# %%
size(300, 200)
rect_mode(CENTER)
for _ in range(20):
    rect(random_int(width), random_int(height), 10, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200>

# %% [markdown]
# Now time to sketch!

# %%
size(400, 400)
rect_mode(CENTER)
for _ in range(20):
    rect(random_int(width), random_int(height), 10, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)
rect_mode(CENTER)

# Set background to a random color
background(random_int(255), random_int(255), random_int(255))

for _ in range(20):
    # Fill little square with a random hex color
    fill(random_int(255), random_int(255), random_int(255))

    rect(random_int(width), random_int(height), 10, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
