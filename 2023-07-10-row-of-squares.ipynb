# %%
def row_of_squares(n=10):
    [square(x * 24 + 100, 100, 20) for x in range(n)]
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
size(400, 400)
background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
square(100, 100, 200)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)
background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
[square(x * 10 + 100, 100, 20) for x in range(10)]
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)
background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
[square(x * 24 + 100, 100, 20) for x in range(10)]
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)
background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
row_of_squares(4)
# Out:
# py5 encountered an error in your code:
#
#
#     1
#     2    background(255)
#     3    fill(255, 0, 0)
#     4    stroke(128, 0, 0)
# --> 5    row_of_squares(4)
#
# NameError: The name "row_of_squares" is not defined.

# %%
def row_of_squares(n=10):
    [square(x * 24 + 100, 100, 20) for x in range(n)]

size(400, 400)
background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
row_of_squares(4)
# Out:
# There is a problem with your code.
# The function call to size (on line 4) must be moved to the beginning of your code, before any other code.

# %%
size(400, 400)

def row_of_squares(n=10):
    [square(x * 24 + 100, 100, 20) for x in range(n)]

background(255)
fill(255, 0, 0)
stroke(128, 0, 0)
row_of_squares(4)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
