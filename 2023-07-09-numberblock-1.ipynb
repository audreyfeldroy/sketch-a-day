# %% [markdown]
# ```
# . ./.venv/bin/activate
# jupyter notebook
# ```
#
# Copy url from terminal
#
# VSCode > Select Kernel > Select Jupyter Server > URL
#
# Paste URL from terminal

# %%
size(400, 400)
background('#00FFFF')

# 2 dark red ellipses below the red square
fill('#8B0000')
ellipse(164, 270, 16, 60)
ellipse(234, 270, 16, 60)

# Red square
fill('#FF0000')
rect(150, 150, 100, 100)

# Draw a circle with white fill and dark red stroke
fill('#FFFFFF')
stroke('#8B0000')
circle(200, 200, 40)

# Draw a circle with black fill and no stroke
fill('#000000')
# stroke(None)
circle(200, 200, 14)

# Set text size to 20
text_size(50)

# Text "1" above the square, size 20
text('1', 191, 140)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
