# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(100, 100, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(200, 200, 100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(200, 200, 200)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(200, 100, 200)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(200, 100, 300)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
size(400, 400)

def draw_fractal(x, y, n):
    """ Draw a fractal with squares """
    square(x, y, n)
    if n > 20:
        draw_fractal(x + n, y, n - 20)
        draw_fractal(x - n, y, n - 20)

draw_fractal(200, 25, 350)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
